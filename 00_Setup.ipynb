# %%
from google.colab import drive
drive.mount('/content/drive')

BASE = '/content/drive/MyDrive/Text Miners/Actual Work'

import os

# Check if the base directory exists
if not os.path.exists(BASE):
    print(f"❌ Error: The directory '{BASE}' does not exist.")
    print("Please ensure the path to 'Text Miners/Actual Work' in your Google Drive is correct.")
    print("You might need to create these folders or adjust the `BASE` variable.")
else:
    folders = os.listdir(BASE)
    print("✅ Connected! Folders found:")
    for f in folders:
        print(f"   📁 {f}")
# Out:
# Mounted at /content/drive
# ✅ Connected! Folders found:
#    📁 data
#    📁 pre-processing
#    📁 features
#    📁 task1-sentiments
#    📁 task2-topics
#    📁 task3-combination
#    📁 dashboard
#    📁 BeforeYouStart.docx
