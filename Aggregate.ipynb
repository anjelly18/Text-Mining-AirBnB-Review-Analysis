# %%
# !pip install gensim pyLDAvis ftfy --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 37.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 69.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.2 MB/s eta 0:00:00

# %%
pip install scikit-learn

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

BASE = '/content/drive/MyDrive/Text Miners/Actual Work'
print('Connected:', BASE)

import os
print(os.listdir(BASE))
# Out:
# Mounted at /content/drive
# Connected: /content/drive/MyDrive/Text Miners/Actual Work
# ['data', 'pre-processing', 'features', 'task1-sentiments', 'task2-topics', 'task3-combination', 'dashboard', 'BeforeYouStart.docx']

# %%
import pickle
import os

BASE = '/content/drive/MyDrive/Text Miners/Actual Work'

# Check all shared feature files exist
files_to_check = [
    f'{BASE}/features/tfidf_matrix.pkl',
    f'{BASE}/features/tfidf_vectorizer.pkl',
    f'{BASE}/features/bow_matrix.pkl',
    f'{BASE}/features/bow_vectorizer.pkl',
    f'{BASE}/features/word2vec.model',
    f'{BASE}/data/MergedCleaned.csv',
    f'{BASE}/data/labelled_reviews.csv',
]

print('Checking shared files...')
all_good = True
for f in files_to_check:
    exists = os.path.exists(f)
    status = '✅' if exists else '❌ MISSING'
    print(f'  {status} {f.split("/")[-1]}')
    if not exists:
        all_good = False

print('\n✅ All files found!' if all_good else '\n❌ Some files missing — check above')
# Out:
# Checking shared files...
#   ✅ tfidf_matrix.pkl
#   ✅ tfidf_vectorizer.pkl
#   ✅ bow_matrix.pkl
#   ✅ bow_vectorizer.pkl
#   ✅ word2vec.model
#   ✅ MergedCleaned.csv
#   ✅ labelled_reviews.csv
#
# ✅ All files found!

# %%
# Out:
# Loading shared features...
# ✅ TF-IDF matrix: (380505, 10000)
# ✅ BoW matrix: (380505, 10000)
# ✅ TF-IDF vectorizer: 10000 words
# ✅ BoW vectorizer: 10000 words
# ✅ Word2Vec: 28321 words in vocabulary
# ✅ Labelled reviews: (380505, 4)
#    Label distribution:
# label
# positive    359559
# neutral      14784
# negative      6162
# Name: count, dtype: int64
